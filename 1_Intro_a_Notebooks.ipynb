# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielsanchez/sistemas-musicales-inteligentes/blob/master/1_Intro_a_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro a Notebooks

# %% [markdown]
# ## Google Colab
# Para este taller utilizaremos Google Colab - un entorno de programación con Notebooks que nos permite ejecutar código, visualizar gráficas e inclusive entrenar modelos de deep learning con GPU.

# %% [markdown]
# ### pwd
# pwd (print working directory) nos permite ver en el directorio en el que estamos trabajando. Recordar que tenemos que utilizar un signo de exclamación **!** antes para que funciones

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ### ls
# ls lista los contenidos del directorio en el que estamos.

# %%
# !ls
# Out:
# sample_data

# %%
# !ls /usr/bin
# Out:
# '['				      mpicxx.openmpi
#  2to3-2.7			      mpiexec
#  7z				      mpiexec.openmpi
#  7za				      mpif77
#  7zr				      mpif77.openmpi
#  acyclic			      mpif90
#  add-apt-repository		      mpif90.openmpi
#  addpart			      mpifort
#  addr2line			      mpifort.openmpi
#  apropos			      mpirun
#  apt				      mpirun.openmpi
#  apt-add-repository		      mtrace
#  apt-cache			      namei
#  apt-cdrom			      native2ascii
#  apt-config			      nawk
#  apt-extracttemplates		      ncal
#  apt-ftparchive			      ncurses5-config
#  apt-get			      nearblack
#  apt-key			      neato
#  apt-mark			      neqn
#  apt-sortpkgs			      newgrp
#  ar				      nice
#  arch				      nl
#  as				      nm
#  asan_symbolize			      nohup
#  asan_symbolize-6.0		      nop
#  assistant			      nproc
#  awk				      nroff
#  b2				      nsenter
#  b2sum				      numfmt
#  base32				      nvidia-bug-report.sh
#  base64				      nvidia-cuda-mps-control
#  basename			      nvidia-cuda-mps-server
# ...

# %% [markdown]
# ### wget
# Nos permite descargar contenido dado un enlace.

# %%
# !wget https://dl.dropbox.com/s/puu5nn26hx0ivs2/drums.zip

# %% [markdown]
# ### find
# Encontrar archivos.

# %%
# !find / -name "*.txt" -ls
# Out:
#   2359692      4 -rw-r--r--   1 root     root         2390 Jul 18 18:21 /etc/java-11-openjdk/security/policy/README.txt
#   2359362     20 -rw-r--r--   1 root     root        17394 Jan 20  2017 /etc/X11/rgb.txt
#   2099370      0 lrwxrwxrwx   1 root     root           23 Oct 15  2018 /usr/share/doc/mount/mount.txt -> ../util-linux/mount.txt
#    395157      4 -rw-r--r--   1 root     root         2834 Sep  1  2015 /usr/share/doc/p7zip/DOC/Methods.txt
#   3150751      4 -rw-r--r--   1 root     root         2105 Nov 21  2015 /usr/share/doc/libaec0/license.txt
#    395254      4 -rw-r--r--   1 root     root         3251 Sep 17  2017 /usr/share/doc/python-numpy/THANKS.txt
#    394409      4 -rw-r--r--   1 root     root         2730 Mar 16  2018 /usr/share/doc/libvorbis-dev/html/vorbis-errors.txt
#    394135      4 -rw-r--r--   1 root     root         1920 Mar  1  2018 /usr/share/doc/libsdl2-2.0-0/CREDITS.txt
# ...

# %% [markdown]
# ### Subir archivos a Colab

# %%
from google.colab import files
uploadedFile = files.upload()
# Out:
#      <input type="file" id="files-bac5938a-caa5-4ce8-8553-4363720a946d" name="files[]" multiple disabled />
#      <output id="result-bac5938a-caa5-4ce8-8553-4363720a946d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ### Clonar repositorio de Github

# %%
# !git clone https://github.com/gabrielsanchez/sistemas-musicales-inteligentes.git
# Out:
# Cloning into 'sistemas-musicales-inteligentes'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# !ls
# Out:
# sample_data  sistemas-musicales-inteligentes

# %% [markdown]
# ### Instalar software

# %%
# !sudo apt-get install locate
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   locate
# 0 upgraded, 1 newly installed, 0 to remove and 8 not upgraded.
# Need to get 52.3 kB of archives.
# After this operation, 181 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 locate amd64 4.6.0+git+20170828-2 [52.3 kB]
# Fetched 52.3 kB in 1s (90.7 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package locate.
# ...
